# %%
print()

# %%
from langchain.tools import tool
from dotenv import load_dotenv

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model='llama-3.3-70b-versatile')

# %%
llm.invoke('hI')
# Out:
# AIMessage(content="It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 37, 'total_tokens': 60, 'completion_time': 0.06367559, 'completion_tokens_details': None, 'prompt_time': 0.001719303, 'prompt_tokens_details': None, 'queue_time': 0.056922956, 'total_time': 0.065394893}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f14f7-4916-7a70-ac4d-ca775d29db5d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 23, 'total_tokens': 60})

# %%
@tool
def multiple(a:int,b:int) -> int:
    """ This is the tool for multiplication
    """
    return a*b

# %%
from langchain_core.tools import StructuredTool

# %%
def get_weather(city:str) -> str:
    """
    Get the weather for given city.
    
    Args:
        city (str): the name of the city>
    
    return:
        str: A string describing the weater in the city
    """
    return f"The weather in the {city} is sunny"

# %%
weather_tool = StructuredTool.from_function(
    func = get_weather,
    name = 'get_weather',
    description='fetches real-time data for a city',
    args_schema=WeatherInput,
)

# %%
import requests; print(requests.get().json())
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 297.57, 'feels_like': 297.37, 'temp_min': 296.75, 'temp_max': 298.76, 'pressure': 1023, 'humidity': 50, 'sea_level': 1023, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 274, 'gust': 2.68}, 'clouds': {'all': 65}, 'dt': 1782911678, 'sys': {'type': 2, 'id': 2075535, 'country': 'GB', 'sunrise': 1782877643, 'sunset': 1782937258}, 'timezone': 3600, 'id': 2643743, 'name': 'London', 'cod': 200}

# %%
lst = ['1',2,3,4,[1,2,4],8,9]
lst[4][0]
# Out:
# 1

# %%
slice = lst[0:5]
slice
# Out:
# ['1', 2, 3, 4, [1, 2, 4]]

# %%
slice[4] = slice[4][0]

# %%
slice
# Out:
# ['1', 2, 3, 4, 1]

# %%
import numpy as np

arr = np.array([1,2,3,4,5,6,7])

# %%
arr[1:5]
# Out:
# array([2, 3, 4, 5])
